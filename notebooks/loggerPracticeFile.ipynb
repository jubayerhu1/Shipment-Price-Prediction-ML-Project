# %%
import logging 
import os

# %%
LOG_DIR = "LogTest"    # folder name : log

LOG_FILE_NAME ="application.log"    # file name

# %%
#  folde make 
os.makedirs(LOG_DIR, exist_ok=True)

# %%
# path difine 
# manul approach
# path = "log/application.log"

# programing approach 
log_path = os.path.join(LOG_DIR,LOG_FILE_NAME)
print(log_path)         # / for mac and \ for windows
# Out:
# LogTest/application.log

# %%
# Configuration
logging.basicConfig(
    filename=log_path,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    level= logging.INFO
)

# %%
def profile(name):
    if type(name)== str:
        print(f"welcome {name}")
    else:
        logging.info("Your input is not valied")

# %%
profile("jubayer")
# Out:
# welcome jubayer

# %%
profile(123)

# %%
def profile_1(name):
    #try:
        if type(name) == str:
            print(f"welcome {name}")
        else:
    #except Exception as e:
            logging.info("not valied")

# %%
profile_1(12)

# %%
def devide_numbers(a,b):
    if b == 0:
        logging.info("Can't devide numbers with 0")
    else:
        return a/b

# %%
devide_numbers(3,0)

# %%
# let's read a file 

try:
     with open('files/amples.txt10','r') as f:
          print(f.read())

except Exception as e :
     logging.info(e)

# %%
def test():
    name = input("enter : ")

    if name == "ju":
        print("ok")
    else:
        print("Not ok")

# %%
test()
# Out:
# ok

# %%
class d:

    def __init__(self):
        self.test()
        
    def test(self):

        name = input("enter : ")

        if name == "ju":
             print("ok")
        else:
            print("Not ok")

# %%
a =d()
# Out:
# ok
