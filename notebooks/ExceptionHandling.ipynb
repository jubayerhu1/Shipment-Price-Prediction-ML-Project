# %%
# Exception handling in python
'''
There are 2 stages where error may happen in a program
    -During compilation -> sysntax error
    - During Execution -> Exceptions.

Syntax Error : 
    - Something in the program is not written according to the program .
    - Error is raised by the interpreter / compiler
    - You can solve it by rectifying the program.
'''

# %%
## raise Exception in Python 
### code brak not to run | directly break the code 

raise Exception ("There is an error")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 ## raise Exception in Python
#       2 ### code brak not to run
#       3
# ----> 4 raise Exception ("There is an error")
#
# Exception: There is an error

# %%
raise ZeroDivisionError("Can't devide with -0")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 raise ZeroDivisionError("Can't devide with -0")
#
# ZeroDivisionError: Can't devide with -0

# %%
# 
raise NameError("Name is not valied")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 #
# ----> 2 raise NameError("Name is not valied")
#
# NameError: Name is not valied

# %%
def devide_numbers(a,b):
    if b ==0 :
        raise Exception("Can't devide number with 0 ")
    else : 
        return a/b

# %%
devide_numbers(3,0)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 devide_numbers(3,0)
#
# Cell In[7], line 3, in devide_numbers(a, b)
#       1 def devide_numbers(a,b):
#       2     if b ==0 :
# ----> 3         raise Exception("Can't devide number with 0 ")
#       4     else :
#       5         return a/b
#
# Exception: Can't devide number with 0
