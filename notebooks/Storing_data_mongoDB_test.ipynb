# %%
print("Ok")
# Out:
# Ok

# %%
import pandas as pd

# %%
# %pwd
# Out:
# 'd:\\Bappy\\Live Sessions\\Inception\\FSDS-with-GenAI-1.0\\ML\\Shipment-Price-Prediction-ML-Project\\notebooks'

# %%
# %pwd
# Out:
# '/Volumes/study/Projects/Shipment-Price-Prediction-ML-Project/notebooks'

# %%
data = pd.read_csv("../data/Shipment-data.csv")

# %%
data

# %%
data.head()
# Out:
#             Customer Id     Artist Name  Artist Reputation  Height  Width  \
# 0  fffe3900350033003300   Billy Jenkins               0.26    17.0    6.0
# 1  fffe3800330031003900     Jean Bryant               0.28     3.0    3.0
# 2  fffe3600370035003100    Laura Miller               0.07     8.0    5.0
# 3      fffe350031003300  Robert Chaires               0.12     9.0    NaN
# 4  fffe3900320038003400    Rosalyn Krol               0.15    17.0    6.0
#
#    Weight   Material  Price Of Sculpture  Base Shipping Price International  \
# 0  4128.0      Brass               13.91                16.27           Yes
# 1    61.0      Brass                6.83                15.00            No
# 2   237.0       Clay                4.96                21.18            No
# 3     NaN  Aluminium                5.81                16.31            No
# 4   324.0  Aluminium                3.18                11.94           Yes
#
#   Express Shipment Installation Included Transport Fragile  \
# ...

# %%
data.tail()
# Out:
#                Customer Id          Artist Name  Artist Reputation  Height  \
# 6495  fffe3800370037003300  Jeffrey Freudenthal               0.37    37.0
# 6496      fffe310036003400        Larry Edwards               0.67    15.0
# 6497  fffe3600300031003300         Denise Worth               0.68    19.0
# 6498  fffe3600350035003900          Daniel Drew               0.02    33.0
# 6499  fffe3700310031003600       Vernon Carroll               0.18    30.0
#
#       Width     Weight Material  Price Of Sculpture  Base Shipping Price  \
# 6495   10.0    16551.0    Brass               28.28                38.46
# 6496    NaN    18981.0      NaN               67.18                27.72
# 6497    8.0      587.0     Clay                6.92                10.38
# 6498    9.0  1269377.0    Stone             2929.13                69.76
# 6499   13.0    34729.0    Brass               46.63                78.25
#
# ...

# %%
data.shape
# Out:
# (6500, 20)

# %%
data.columns
# Out:
# Index(['Customer Id', 'Artist Name', 'Artist Reputation', 'Height', 'Width',
#        'Weight', 'Material', 'Price Of Sculpture', 'Base Shipping Price',
#        'International', 'Express Shipment', 'Installation Included',
#        'Transport', 'Fragile', 'Customer Information', 'Remote Location',
#        'Scheduled Date', 'Delivery Date', 'Customer Location', 'Cost'],
#       dtype='str')

# %%
type(data)
# Out:
# pandas.DataFrame

# %%
# conver data dict for MongoDB
data_dic = data.to_dict(orient='records')

# %%
data_dic

# %%
len(data_dic)
# Out:
# 6500

# %%
DB_NAME = "ShipmentDB"
COLLECTION_NAME = "shipment_collection"
CONNECTION_URL = "Your_Mongo_DB_Connection_URL"

# %%
import pymongo

client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %% [markdown]
# # Storing Data to MongoDB Database

# %%
rec = collection.insert_many(data_dic)

# %% [markdown]
# # Fetching Data from MongoDB Database

# %%
records = collection.find()

# %%
records

# %%
for i in records:
    print(i)

# %%
df = pd.DataFrame(list(collection.find()))

# %%
df.head()
# Out:
#                         _id           Customer Id     Artist Name  \
# 0  6a094ee8ed945e7da953b648  fffe3900350033003300   Billy Jenkins
# 1  6a094ee8ed945e7da953b649  fffe3800330031003900     Jean Bryant
# 2  6a094ee8ed945e7da953b64a  fffe3600370035003100    Laura Miller
# 3  6a094ee8ed945e7da953b64b      fffe350031003300  Robert Chaires
# 4  6a094ee8ed945e7da953b64c  fffe3900320038003400    Rosalyn Krol
#
#    Artist Reputation  Height  Width  Weight   Material  Price Of Sculpture  \
# 0               0.26    17.0    6.0  4128.0      Brass               13.91
# 1               0.28     3.0    3.0    61.0      Brass                6.83
# 2               0.07     8.0    5.0   237.0       Clay                4.96
# 3               0.12     9.0    NaN     NaN  Aluminium                5.81
# 4               0.15    17.0    6.0   324.0  Aluminium                3.18
#
#    Base Shipping Price  ... Express Shipment Installation Included Transport  \
# ...

# %%
if "_id" in df.columns:
    df.drop(columns=["_id"], inplace=True)

# %%
df.head()
# Out:
#             Customer Id     Artist Name  Artist Reputation  Height  Width  \
# 0  fffe3900350033003300   Billy Jenkins               0.26    17.0    6.0
# 1  fffe3800330031003900     Jean Bryant               0.28     3.0    3.0
# 2  fffe3600370035003100    Laura Miller               0.07     8.0    5.0
# 3      fffe350031003300  Robert Chaires               0.12     9.0    NaN
# 4  fffe3900320038003400    Rosalyn Krol               0.15    17.0    6.0
#
#    Weight   Material  Price Of Sculpture  Base Shipping Price International  \
# 0  4128.0      Brass               13.91                16.27           Yes
# 1    61.0      Brass                6.83                15.00            No
# 2   237.0       Clay                4.96                21.18            No
# 3     NaN  Aluminium                5.81                16.31            No
# 4   324.0  Aluminium                3.18                11.94           Yes
#
#   Express Shipment Installation Included Transport Fragile  \
# ...

# %%
df.to_csv("shipment_data.csv", index=False)
